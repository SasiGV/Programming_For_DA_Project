# %% [markdown]
# # Programming-for-DataAnalysis
#
# ## Project for Semester 2 - 2019¶
#
# ### Student Name : Sasikala Varatharajan
#
# ### Student Number : G00376470

# %% [markdown]
# ### About Project
#
# For this project a data set must be created by simulating a real-world phenomenon. As I am interested in walking with my family I would like to investigate the factors that could affect the exercise or walking timing of a normal person.
# It was suggested to use the numpy.random package for this purpose and Python programming for modeling and synthesise the data.
#
# This project includes:
#
# • Real-world phenomenon that can be measured and for which could collect at least one-hundred data points across at least four different variables.
#
# • Investigation of the types of variables involved, their likely distributions, and their relationships with each other.
#
# • Simulation of a data set as closely matching their properties as possible.
#
# • Description of the research and implemention of the simulation in a Jupyter notebook – the data set itself can simply be displayed in an output cell within the notebook.

# %% [markdown]
# ### About the Dataset
#
# #### Dataset Name: Healthy Town
#
# This project has a review of how healthy the people in a selected town by reviewing their walking habit and the factors that affects the walking habit from various group of people. This also has a simulator written by Python Programming language to generate a dataset to review the relationship between the selected variables.
#
# Exercising every day or going for a walk will improve health and at the same time it will also give us a chance to meet people. Most of the people in the middle age and family with kids find it bit hard to find time to go for a walk. When I had the same difficulty with kids I found a walking club and helping hands. Slowly I have got in to the routine to go for walk with kids and I found myself happy whenever I go out with kids. While I was looking for real time phenomenon for this project I have decided to do a research what are the factors affects and supports for walking.
#
# In this project I have taken few factors to discuss about the relationship between them and how they affect the walking habit. Based on the analysis we can see how healthy/ happy the people live in the selected town.
#
#
# #### Variables:
#
# 1. Season : Four different Seasons in Ireland is playing a big role in walking outside as this could affect people's mood.
# 2. Weather :Rainy or Dry
# 3. Daytype: Dry or Wet days
# 4. Walkers: Total number of walkers based on the age group
# 5. Mood_Status: Based on

# %% [markdown]
# #### Selected Town: Monaghan Town, Co-Monaghan, Ireland
# Monaghan is a small town and based on Ireland’s census I have taken that there are around 60,500 people at different age group in the Town. There are few walking clubs available to encourage walkers. Country side walker clubs have guides as well to help the walkers. Most of the walking areas are open to public all day in the year.
#
# #### Selected variables:
# ##### Season:
# Different seasons in Ireland has different climate which has a huge impact in the walking timing from different group of people. I am using the following seasons as one of my variables.
#
# ###### Spring (March - May)
# In spring it becomes gradually warmer with average temperatures between 8 - 12 °C. Towards the end of the season, the temperature often reaches 15 °C, with April usually being a particularly pleasant month. Long sleeves and a light wind and waterproof jacket are perfect for this kind of weather.
#
# ###### Summer (June - August)
# The average temperature during the summer is between 16-20 °C. Apart from short refreshing showers, this is Ireland’s driest season. Take a light raincoat but also sunglasses! Although the sun may not seem very bright, it is still important to use sunscreen. The hottest months, July and August, get about 18 hours of daylight, only turning dark after 11pm in the evening. Hence the well-known saying in Ireland, “make the most of your evening”.
#
# ###### Autumn (September - November)
# In autumn, the temperature ranges between 14-18 °C. September is considered a mild, moderate month. The season is characterised by beautiful autumn colours and slightly more frequent rainfall than in summer. The temperature will drop further at the end of the season, to below 10 °C. Take a waterproof, padded jacket and long sleeves to stay warm and dry.
#
# ###### Winter (December - February)
# The average temperature during the winter ranges between 4-6 °C. Occasionally, the temperature drops below freezing and apart from a few brief periods of cold, snow is rare. The rain can make it feel colder than it is, so a warm waterproof winter coat will keep you warm. The Irish themselves enjoy visiting cosy pubs (preferably with a crackling log fires) a little more frequently during the winter season.
#
# #### Weather:
# Now a day’s weather is playing a big role when people try to go for a walk. Especially people who are working full time during the weekdays will prefer to do indoor exercises when it is rainy outside. I have taken rain and dry climates as key factors in the research to find out how it is affecting walking outside.
#
# #### Day type:
# During summer we might see dry days even if it has reasonable rainfall.  Very few days in autumn season might get strong rainfall during the day time but it will only last for few minutes.  There are plenty of tips available from walking clubs to find out what to wear during rainy days and cold weather.
#
# Based on the weather condition and day type I have used my assumption to figure out how many people from different age group will go for walk.
#
# Age group:
# I have classified different age group by my assumption as per below
# Group 1: Age from 15 – 25 – 20% of total population
# Group 2: Age from 26 – 40 – 20% of total population
# Group 3: Age from 41 – 51 – 30% of total population
# Group 4: Age above 50 – 20% of total population
#
# #### Walkers: Tot. Number of walkers
# There could be different factors for each group of people which could stop them from walking or from other exercises.  As per my experiences and my assumptions any one or group of the following factors will affect the regular activities. I assume that around 20% of people in each group might get these problems.
#
# Working patterns
# Family with small kid(s)
# Sickness
# Exams
# Party or visitors
# Extra-curricular activities
#
# #### Health_status:
# Based on the total number of walkers I am calculating the percentage of walkers for the selected day. If the w
#
# In order to be healthy I would prefer everyone must have at least half an hour walking time in a day but for various reasons it is not achievable by everyone.   While calculating the number of walkers for a day, I am actually taking weather and day type to find out how supportive it is.  If it is rainy and wet during winter season then rain and wet proportion will also affect the walkers.
#
# So the factors Season, weather and day type play a major role in calculating the total number of walkers in a day.
#
# ##### Benefits of Walking:
# Instead of sitting for long hours walking and other activities will help us improve our health and that will also make us happy. Scientist has found that while exercising human body can produce Dopamine one of the hormone which will make us happy.
# It improves self-perception and self-esteem, mood and sleep quality, and it reduces stress, anxiety and fatigue. Physically active people have up to a 30% reduced risk of becoming depressed, and staying active helps those who are depressed recover.
# In older people, staying active can improve cognitive function, memory, attention and processing speed, and reduce the risk of cognitive decline and dementia.
#
# All adults (including adults with disabilities and older adults)Strong evidence of:
# better cardio-respiratory and muscular fitness
# less weight gain
# more weight loss – combined with eating fewer calories
# better weight maintenance after weight loss
# lower risk of early death
# lower risk of stroke
# lower risk of coronary heart disease
# lower risk of high blood pressure
# lower risk of unhealthy blood lipid profile
# lower risk of type 2 diabetes
# lower risk of metabolic syndrome
# lower risk of colon and breast cancer
# fewer falls
# reduced levels depression
# better cognitive function in older adults
#
# [https://www.smartertravelworkplaces.ie/step-challenge/benefits-of-walking/?fireglass_rsn=true]
# Walking to Work:
# The numbers walking to work in 2016 increased to 175,080, up by 4,570 persons from 2011, although walkers accounted for less than 1 in 10 of the commuting population compared with 15 per cent in 1986. In 2016, almost 55 per cent of commuting walkers were women, with 45 per cent male, the opposite of 1986 when men accounted for 51.4 per cent.
# [https://www.cso.ie/en/releasesandpublications/ep/p-cp6ci/p6cii/p6mtw/?fireglass_rsn=true]

# %%
# This code imports python libraries.

# import numpy for use of arrays\n",
import numpy as np
# import pandas to use DataFrames
import pandas as pd
# import seaborn for ploting
import seaborn as sns
# import matplotlib pyplot for ploting
import matplotlib.pyplot as plt

# %%
# Code to creates data points for each season in the year

# Assuming that number of data points for each season is 90 [Approx 90 days for 3 months]
dp_season = 90

# Create list with same amount of data points for each season. Code adpted from
# https://stackoverflow.com/questions/3459098/create-list-of-single-item-repeated-n-times/3459140#3459140
ds_seasons = ["winter"]*dp_season + ["spring"]*dp_season + ["summer"]*dp_season + ["autumn"]*dp_season

# Create dataframe 'df_Walking_Club' for storing dataset. 
df_Walking_Club = pd.DataFrame(ds_seasons, columns =['seasons'])

# Print Title
print('\nFirst 5 lines of dataset "Walking_Club"')
# Display first 5 lines of dataframe df_Walking_Club
df_Walking_Club.head()
# Out:
# First 5 lines of dataset "Walking_Club"
#   seasons
# 0  winter
# 1  winter
# 2  winter
# 3  winter
# 4  winter

# %%
ls_weather = ['dry', 'rain', 'wet']

# Print Title
print('\nList of possible weather types')
# Display list of rainy weather types
ls_weather
# Out:
# List of possible weather types
# ['dry', 'rain', 'wet']

# %%
# Creates dataframe matrix of average monthly weather data

# Average weather data for Monaghan, Ireland. 
# Rainfall and weather data for Monaghan adapted from
# https://data.gov.ie/dataset/monaghan-knockroe-rainfall-data &
# https://en.climate-data.org/europe/ireland/monaghan/monaghan-11695/

rain_days_month = [26, 17, 20, 21, 13, 9, 11, 24, 17, 17, 21, 20]
wet_days_month = [22, 14, 13, 14, 10, 6, 7, 18, 12, 9, 17, 17]
days_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
mm_rain_month = [201.4, 80.5, 62.6, 61.7, 46, 80.6, 49.1, 92.6, 44.8, 30.7, 124.8, 103]
min_temp = [1.2, 1.2, 2.3, 3.6, 6.2, 8.9, 10.6, 10.2, 8.7, 6.6, 3.1, 2.1]
max_temp = [6.6, 7 ,9.1, 11.6, 14.5, 17.3, 18.5, 18.2, 16.1, 13, 9, 7.4]

# Create dataframe with rain data. Code adapted from
# https://www.geeksforgeeks.org/create-a-pandas-dataframe-from-lists/
df_Average_monthly_weather = pd.DataFrame(list(zip(rain_days_month, wet_days_month, days_month, mm_rain_month, min_temp, max_temp)), 
                    index =['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                           'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
                   columns=['rain_days_month', 'wet_days_month', 'days_month', 'mm_rain_month', 'min_temp', 'max_temp'])

# Calculate proportion of rain fall and wet days in a month
df_Average_monthly_weather['rain_month_proportion'] = df_Average_monthly_weather.apply(lambda row: np.round(row.rain_days_month/row.days_month,3), axis=1)
df_Average_monthly_weather['wet_month_proportion'] = df_Average_monthly_weather.apply(lambda row: np.round(row.wet_days_month/row.days_month,3), axis=1)

# Print data from dataframe
print('\nMonthly average weather data for Monaghan Town')
df_Average_monthly_weather
# Out:
# Monthly average weather data for Monaghan Town
#      rain_days_month  wet_days_month  days_month  mm_rain_month  min_temp  \
# Jan               26              22          31          201.4       1.2
# Feb               17              14          28           80.5       1.2
# Mar               20              13          31           62.6       2.3
# Apr               21              14          30           61.7       3.6
# May               13              10          31           46.0       6.2
# Jun                9               6          30           80.6       8.9
# Jul               11               7          31           49.1      10.6
# Aug               24              18          31           92.6      10.2
# Sep               17              12          30           44.8       8.7
# Oct               17               9          31           30.7       6.6
# Nov               21              17          30          124.8       3.1
# ...

# %%
# Find weather types using the list values for weather 
# for each data point in dataframe 'df_Walking_Club'

# Set list of months in each season
winter = ['Nov', 'Dec', 'Jan']
spring = ['Feb', 'Mar', 'Apr']
summer = ['May', 'Jun', 'Jul']
autumn = ['Aug', 'Sep', 'Oct']

# Function to predict month from a list of months in a given season
def Find_Month(a):
    # Documentation string
    """Returns a random choice of month within a given season"""
    
    # Check for winter season
    if a == 'winter':
        # Set season to winter list
        season = winter
    
    # Check for spring season    
    elif a == 'spring':
        # Set season to spring list
        season = spring
    
    # Check for summer season
    elif a == 'summer':
        # Set season to summer list
        season = summer
    
    # Otherwise season is autumn
    else:
        # Set season to autumn list
        season = autumn          
    
    # Return a month choosen randomly with uniform distribution within a given season list
    return np.random.choice(a=season)

# Apply the function 'Find_Month' to each row in dataframe 'df_Walking_Club'
df_Walking_Club["month"] = df_Walking_Club.apply(lambda row: Find_Month(row.seasons), axis=1)


# Function to predict weather based on month
def weather_type(Month):
    # Documentation string
    """Returns a choice of either 'dry' or 'wet' based on 
            mean number of day with rain in a given month"""
    
    # Select proportion of days with rain in a given month in
    # DataFrame 'df_Walking_Club' based on column and row index. Code adapted from 
    # https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html
    weather = df_Average_monthly_weather.rain_month_proportion.loc[str(Month)]
    
    # Return a weather type based on amount of rain in month
    return np.random.choice(a=['dry',  'rain'], p=[(1-weather), weather])

# Apply the function 'df_Walking_Club' to each row in dataframe 'park'
df_Walking_Club["weather"] = df_Walking_Club.apply(lambda row: weather_type(row.month), axis=1)


# Function to predict weather based on month
def day_type(Month):
    # Documentation string
    """Returns a choice of either 'dry' or 'rain' based on 
            mean number of day with rain in a given month"""
    
    # Select proportion of days with rain in a given month in
    # DataFrame 'df_Walking_Club' based on column and row index. Code adapted from 
    # https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html
    Day = df_Average_monthly_weather.wet_month_proportion.loc[str(Month)]
    
    # Return a weather type based on amount of rain in month
    return np.random.choice(a=['dry',  'wet'], p=[(1-Day), Day])

# Apply the function 'df_Walking_Club' to each row in dataframe 'park'
df_Walking_Club["Day"] = df_Walking_Club.apply(lambda row: day_type(row.month), axis=1)



# Print Title
print('\nFirst 5 lines of dataset "df_Walking_Club"')
# Display first 5 lines of dataframe 'df_Walking_Club'
df_Walking_Club.head()
# Out:
# First 5 lines of dataset "df_Walking_Club"
#   seasons month weather  Day
# 0  winter   Dec    rain  dry
# 1  winter   Nov    rain  dry
# 2  winter   Jan    rain  wet
# 3  winter   Jan    rain  dry
# 4  winter   Nov    rain  dry

# %%
# Print Title
print('\nDaily summary of weather and months in dataset "df_Walking_Club"')
# Display daily summary of weather and months
# Code adapted from https://dfrieds.com/data-analysis/crosstabs-python-pandas
pd.crosstab(index=df_Walking_Club['Day'], columns=df_Walking_Club['month'], margins=True)
# Out:
# Daily summary of weather and months in dataset "df_Walking_Club"
# month  Apr  Aug  Dec  Feb  Jan  Jul  Jun  Mar  May  Nov  Oct  Sep  All
# Day
# dry     20   15   16   20   11   23   23   18   17   14   16   20  213
# wet     12   12   21   14   19    9    8    6   10    9    7   20  147
# All     32   27   37   34   30   32   31   24   27   23   23   40  360

# %%
# Print Title
print('\nDaily summary of weather and months in dataset "df_Walking_Club"')
# Display daily summary of weather and months
# Code adapted from https://dfrieds.com/data-analysis/crosstabs-python-pandas
pd.crosstab(index=df_Walking_Club['weather'], columns=df_Walking_Club['month'], margins=True)
# Out:
# Daily summary of weather and months in dataset "df_Walking_Club"
# month    Apr  Aug  Dec  Feb  Jan  Jul  Jun  Mar  May  Nov  Oct  Sep  All
# weather
# dry        9    8   11    9    7   17   22   10   17    4    7   13  134
# rain      23   19   26   25   23   15    9   14   10   19   16   27  226
# All       32   27   37   34   30   32   31   24   27   23   23   40  360

# %%
print(df_Walking_Club.to_string())
# Out:
#     seasons month weather  Day
# 0    winter   Dec    rain  dry
# 1    winter   Nov    rain  dry
# 2    winter   Jan    rain  wet
# 3    winter   Jan    rain  dry
# 4    winter   Nov    rain  dry
# 5    winter   Jan    rain  wet
# 6    winter   Jan     dry  wet
# 7    winter   Dec     dry  dry
# 8    winter   Jan    rain  wet
# 9    winter   Dec    rain  dry
# 10   winter   Nov    rain  wet
# 11   winter   Dec    rain  wet
# 12   winter   Nov    rain  wet
# 13   winter   Nov     dry  dry
# 14   winter   Jan    rain  wet
# 15   winter   Dec     dry  wet
# 16   winter   Jan    rain  wet
# 17   winter   Jan    rain  dry
# 18   winter   Dec    rain  dry
# 19   winter   Dec     dry  wet
# 20   winter   Jan    rain  wet
# 21   winter   Nov    rain  dry
# 22   winter   Dec    rain  wet
# 23   winter   Dec    rain  wet
# 24   winter   Nov    rain  wet
# 25   winter   Dec    rain  wet
# 26   winter   Nov    rain  wet
# 27   winter   Jan    rain  dry
# 28   winter   Dec    rain  dry
# ...

# %% [markdown]
# As per latest Censex data collection I am assuming that there are 60500 people living in Monaghan Town and i order to calculate the number of walkers for the selected day, I have separated the people with different age group from 15 to 25, 26 to 40, 41 to 50 and above 50. From the total population I have clasified that 20% o population falls on the age groups 15-25, 26-40 and above 50. I have taken 30% population in the category of age group 41-50.
#
# For each season, based on the weather condition and day type walkers from different age group will be different. In order to find the total walkers for each season I have four different calculations for the different weather and day type.

# %%
Town_Population = 60500
no_of_walkers = 0

Age_15_25 = 0.20 * Town_Population
Age_26_40 = 0.20 * Town_Population
Age_41_50 = 0.30 * Town_Population
Age_above_50 = 0.20 * Town_Population


def Find_walkers(season, weather, day):

  # Check for winter season
    if season == 'winter':
        if weather == 'rain' and day == 'wet':
            no_of_walkers = (Age_15_25 * 0.25) + (Age_26_40 * 0.20) + (Age_41_50 * 0.15) + (Age_above_50 * 0.0)
        elif weather == 'rain' and day == 'dry':
            no_of_walkers = (Age_15_25 * 0.35) + (Age_26_40 * 0.25) + (Age_41_50 * 0.20) + (Age_above_50 * 0.3)
        elif weather == 'dry' and day == 'wet':
            no_of_walkers = (Age_15_25 * 0.40) + (Age_26_40 * 0.30) + (Age_41_50 * 0.25) + (Age_above_50 * 0.4)
        elif weather == 'dry' and day == 'dry':
            no_of_walkers = (Age_15_25 * 0.50) + (Age_26_40 * 0.40) + (Age_41_50 * 0.30) + (Age_above_50 * 0.6)  
    # Check for spring season    
    elif season == 'spring':
        if weather == 'rain' and day == 'wet':
            no_of_walkers = (Age_15_25 * 0.40) + (Age_26_40 * 0.50) + (Age_41_50 * 0.40) + (Age_above_50 * 0.5)
        elif weather == 'rain' and day == 'dry':
            no_of_walkers = (Age_15_25 * 0.45) + (Age_26_40 * 0.55) + (Age_41_50 * 0.45) + (Age_above_50 * 0.6)
        elif weather == 'dry' and day == 'wet':
            no_of_walkers = (Age_15_25 * 0.50) + (Age_26_40 * 0.60) + (Age_41_50 * 0.50) + (Age_above_50 * 0.8)
        elif weather == 'dry' and day == 'dry':
            no_of_walkers = (Age_15_25 * 0.60) + (Age_26_40 * 0.65) + (Age_41_50 * 0.60) + (Age_above_50 * 0.10)  
    # Check for summer season
    elif season == 'summer':
        if weather == 'rain' and day == 'wet':
            no_of_walkers = (Age_15_25 * 0.75) + (Age_26_40 * 0.55) + (Age_41_50 * 0.30) + (Age_above_50 * 0.10)
        elif weather == 'rain' and day == 'dry':
            no_of_walkers = (Age_15_25 * 0.80) + (Age_26_40 * 0.60) + (Age_41_50 * 0.35) + (Age_above_50 * 0.15)
        elif weather == 'dry' and day == 'wet':
            no_of_walkers = (Age_15_25 * 0.80) + (Age_26_40 * 0.60) + (Age_41_50 * 0.32) + (Age_above_50 * 0.12)
        elif weather == 'dry' and day == 'dry':
            no_of_walkers = (Age_15_25 * 0.85) + (Age_26_40 * 0.65) + (Age_41_50 * 0.40) + (Age_above_50 * 0.20)  
    # Otherwise season is autumn
    else:
        if weather == 'rain' and day == 'wet':
            no_of_walkers = (Age_15_25 * 0.40) + (Age_26_40 * 0.40) + (Age_41_50 * 0.30) + (Age_above_50 * 0.8)
        elif weather == 'rain' and day == 'dry':
            no_of_walkers = (Age_15_25 * 0.45) + (Age_26_40 * 0.45) + (Age_41_50 * 0.35) + (Age_above_50 * 0.10)
        elif weather == 'dry' and day == 'wet':
            no_of_walkers = (Age_15_25 * 0.55) + (Age_26_40 * 0.50) + (Age_41_50 * 0.35) + (Age_above_50 * 0.8)
        elif weather == 'dry' and day == 'dry':
            no_of_walkers = (Age_15_25 * 0.60) + (Age_26_40 * 0.60) + (Age_41_50 * 0.40) + (Age_above_50 * 0.10)  
    return int(no_of_walkers)

df_Walking_Club["Tot.Walkers"] = df_Walking_Club.apply(lambda row: Find_walkers(row.seasons, row.weather, row.Day), axis=1)

# Print Title
print('\nFirst 5 lines of dataset "df_Walking_Club"')
# Display first 5 lines of dataframe 'df_Walking_Club'
print(df_Walking_Club.to_string())
# Out:
# First 5 lines of dataset "df_Walking_Club"
#     seasons month weather  Day  Tot.Walkers
# 0    winter   Dec    rain  dry        14520
# 1    winter   Nov    rain  dry        14520
# 2    winter   Jan    rain  wet         8167
# 3    winter   Jan    rain  dry        14520
# 4    winter   Nov    rain  dry        14520
# 5    winter   Jan    rain  wet         8167
# 6    winter   Jan     dry  wet        17847
# 7    winter   Dec     dry  dry        23595
# 8    winter   Jan    rain  wet         8167
# 9    winter   Dec    rain  dry        14520
# 10   winter   Nov    rain  wet         8167
# 11   winter   Dec    rain  wet         8167
# 12   winter   Nov    rain  wet         8167
# 13   winter   Nov     dry  dry        23595
# 14   winter   Jan    rain  wet         8167
# 15   winter   Dec     dry  wet        17847
# 16   winter   Jan    rain  wet         8167
# 17   winter   Jan    rain  dry        14520
# 18   winter   Dec    rain  dry        14520
# ...

# %% [markdown]
# Now I am adding another variable Health_status which is to show the status of healthy people calculated by the percentage of walkers from the total population. Based on this status field we can perdict how healthy the town is and which season is the best one for walking.

# %%
df_Walking_Club['Health_Status'] = np.where((df_Walking_Club['Tot.Walkers'] * 100 / Town_Population) > 40,'Healthy','Below Average')
print(df_Walking_Club.to_string())
# Out:
#     seasons month weather  Day  Tot.Walkers  Health_Status
# 0    winter   Dec    rain  dry        14520  Below Average
# 1    winter   Nov    rain  dry        14520  Below Average
# 2    winter   Jan    rain  wet         8167  Below Average
# 3    winter   Jan    rain  dry        14520  Below Average
# 4    winter   Nov    rain  dry        14520  Below Average
# 5    winter   Jan    rain  wet         8167  Below Average
# 6    winter   Jan     dry  wet        17847  Below Average
# 7    winter   Dec     dry  dry        23595  Below Average
# 8    winter   Jan    rain  wet         8167  Below Average
# 9    winter   Dec    rain  dry        14520  Below Average
# 10   winter   Nov    rain  wet         8167  Below Average
# 11   winter   Dec    rain  wet         8167  Below Average
# 12   winter   Nov    rain  wet         8167  Below Average
# 13   winter   Nov     dry  dry        23595  Below Average
# 14   winter   Jan    rain  wet         8167  Below Average
# ...

# %% [markdown]
# Summarise view of the Data Frame

# %%
df_Walking_Club.describe()
# Out:
#         Tot.Walkers
# count    360.000000
# mean   22169.669444
# std     6314.682484
# min     8167.000000
# 25%    18452.000000
# 50%    24200.000000
# 75%    27527.000000
# max    32065.000000

# %% [markdown]
# Boxplot is used to show the relationship between the fields month and total walkers. Based on this plot we can see that March, February, April, Jun, May and July has walkers above 25000 and October, September and August has between 19000 to 24000 and months during the winter season has below 20000.

# %%
sns.set_style("whitegrid")
#sns.boxplot(x="month", y="Walkers", data = df_Walking_Club)
sns.boxplot(x="month", y="Tot.Walkers", data=df_Walking_Club, palette="husl")
sns.despine()
plt.show()

# %% [markdown]
# From the below plot, it seems very clear that how the type of day affects the walkers. While comparing the walkers during the dry days with wet days, it is very clear that dry days have higher number of walkers than wet days.

# %%
sns.set_style("whitegrid")
#sns.boxplot(x="month", y="Walkers", data = df_Walking_Club)
sns.boxplot(x="Day", y="Tot.Walkers", data=df_Walking_Club, palette="husl")
sns.despine()
plt.show()

# %% [markdown]
# Boxplot below is used to show the relationship between seasons and total number of walkers. From the analysis below we can see that Spring and Summer season has the maximum walkers and the rest of the seasons has below average number of walkers. With this analysis it is clear that Season has a huge impact in the walking outside.

# %%
sns.set_style("whitegrid")
#sns.boxplot(x="month", y="Walkers", data = df_Walking_Club)
sns.boxplot(x="seasons", y="Tot.Walkers", data=df_Walking_Club, palette="husl")
sns.despine()
plt.show()

# %% [markdown]
# From the analysis below it is very clear that the status of the town is showing healthy when there is more than 40% of total population is going for walking.

# %%
sns.set_style("whitegrid")
#sns.boxplot(x="month", y="Walkers", data = df_Walking_Club)
sns.boxplot(x="Health_Status", y="Tot.Walkers", data=df_Walking_Club, palette="husl")
sns.despine()
plt.show()

# %% [markdown]
# From the above analysis with the walkers club dataset, walking habits of different age group of people will be affected by the season, weather condition and day type during the season. When we see more than 40% of total population have time to go for walking then we can say that the town has healthy people. So based on above analysis Monaghan town's people are healthy duing Spring and Summer month and their healthy status is closer to average during Autumn and at below average druing Winter season.

# %% [markdown]
# #### Reference:
#
# Walkers dataset:
#
# https://www.theirelandwalkingguide.com/knowledge-and-skills.html)
#
# Benifits of walking
#
# https://www.theguardian.com/lifeandstyle/2019/jul/28/its-a-superpower-how-walking-makes-us-healthier-happier-and-brainier?fireglass_rsn=true
#
# https://www.ireland.com/en-gb/what-is-available/walking-and-hiking/articles/walking-hiking/?fireglass_rsn=true
#
# https://monaghantourism.com/index.php/walking?fireglass_rsn=true
#
# https://www.walkingforhealth.org.uk/get-walking/why-walk/healthy-minds
#
# https://www.smartertravelworkplaces.ie/step-challenge/benefits-of-walking/?fireglass_rsn=true
#
# https://www.cso.ie/en/releasesandpublications/ep/p-cp6ci/p6cii/p6mtw/?fireglass_rsn=true
#
#
# About Monaghan Climate and walking club
#
# https://en.climate-data.org/europe/ireland/monaghan/monaghan-11695/
#
# https://www.ireland.com/en-gb/about-ireland/discover-ireland/irelands-weather/?fireglass_rsn=true
#
# http://census.cso.ie/sapmap2016/Results.aspx?Geog_Type=ST2016&Geog_Code=A835224B-B92B-4F96-BCA4-0A548751442B&fireglass_rsn=true
#
# https://www.monaghantourism.com/
#
# https://www.walkingforhealth.org.uk/get-walking/why-walk/healthy-bodies
#
#
# Python programming
#
# https://www.geeksforgeeks.org/python-merge-join-and-concatenate-dataframes-using-panda/?fireglass_rsn=true
#
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas?fireglass_rsn=true
#
# https://caisbalderas.com/blog/iterating-with-python-lambdas/?fireglass_rsn=true
#
# https://www.geeksforgeeks.org/g-fact-41-multiple-return-values-in-python/?fireglass_rsn=true
#
# https://stackoverflow.com/questions/48420684/appending-arrays-to-dataframe-python?fireglass_rsn=true
#
# https://jakevdp.github.io/PythonDataScienceHandbook/03.06-concat-and-append.html?fireglass_rsn=true
